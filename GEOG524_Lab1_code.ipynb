# %% [markdown]
# <a href="https://colab.research.google.com/github/atkinsonde/524/blob/main/GEOG524_Lab1_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

### NOTE Osamu told us that we can put files in our Google Drive and then link that to Colab. It saves
###      having to run this upload procedure every time.
# Out:
#      <input type="file" id="files-0c8ac2bf-5fdc-4db4-9819-32a82ebb2ce8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c8ac2bf-5fdc-4db4-9819-32a82ebb2ce8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

temp0=pd.read_csv("temperature1.txt",names=(['day','Td']),dtype={'t':np.float32},sep=" ")

# %%
temp0['Td'].plot()

# %%
temp0

# %%
temp1 = pd.read_csv('temperature1.txt',delim_whitespace=True, names=['day','Td'],index_col='day')

# %%
temp1.plot()

# %%
temp1
# Out:
#        Td
# day
# 1   -28.5
# 2   -28.0
# 3   -28.9
# 4   -30.2
# 5   -31.0
# 6   -34.5
# 7   -35.2
# 8   -35.8
# 9   -36.5
# 10  -37.0
# 11  -36.7
# 12  -35.3
# 13  -34.2
# 14  -33.4
# 15  -32.9
# 16  -32.0
# 17  -31.4
# 18  -30.0
# 19  -29.2
# 20  -29.0
# 21  -28.1
# 22  -27.0
# 23  -25.3
# 24  -25.2
# 25  -25.0
# 26  -24.0
# 27  -25.1
# 28  -26.3
# 29  -28.2
# 30  -27.3
# 31  -24.2

# %%
temp1.describe()
# Out:
#               Td
# count  31.000000
# mean  -30.174194
# std     4.076515
# min   -37.000000
# 25%   -33.800000
# 50%   -29.200000
# 75%   -27.150000
# max   -24.000000
